# %% [markdown]
# # DeepRNN

# %%
import tensorflow as tf 
import keras 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,SimpleRNN 
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Load the dataset
(X_train ,Y_train) ,(X_test,Y_test ) = imdb.load_data(num_words=10000) 

# pad_sequences
X_train =pad_sequences(X_train,maxlen=100)
X_test =pad_sequences(X_test,maxlen=100)

# %%
 # Define the RNN model
 
model = Sequential([
    Embedding(input_dim=10000,output_dim=32,input_length =100) ,# embedding layer to convert words to vectores
    SimpleRNN(5,return_sequences=True),                         # RNN LAYER WITH 5units 
    SimpleRNN(5),
    Dense(1,activation='sigmoid')]) 
model.build(input_shape=(None,100))



model.compile(loss ='binary_crossentropy',optimizer ='adam',metrics =['accuracy'])

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_8 (SimpleRNN)        │ (None, 100, 5)         │           190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_9 (SimpleRNN)        │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 320,251 (1.22 MB)
#  Trainable params: 320,251 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train,Y_train,epochs=20 ,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 58ms/step - accuracy: 0.6247 - loss: 0.6508 - val_accuracy: 0.7561 - val_loss: 0.5318
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.7848 - loss: 0.4773 - val_accuracy: 0.6974 - val_loss: 0.5871
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8161 - loss: 0.4148 - val_accuracy: 0.7531 - val_loss: 0.5603
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 45ms/step - accuracy: 0.8433 - loss: 0.3537 - val_accuracy: 0.7535 - val_loss: 0.5596
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9000 - loss: 0.2557 - val_accuracy: 0.7454 - val_loss: 0.5998
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9276 - loss: 0.2016 - val_accuracy: 0.6408 - val_loss: 1.0232
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9181 - loss: 0.2172 - val_accuracy: 0.7385 - val_loss: 0.6899
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.9515 - loss: 0.1416 - val_accuracy: 0.7328 - val_loss: 0.7571
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.9630 - loss: 0.1125 - val_accuracy: 0.7070 - val_loss: 0.8695
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9652 - loss: 0.1008 - val_accuracy: 0.7199 - val_loss: 0.8803
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9667 - loss: 0.0959 - val_accuracy: 0.7254 - val_loss: 0.8999
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9758 - loss: 0.0767 - val_accuracy: 0.7206 - val_loss: 0.9541
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9789 - loss: 0.0699 - val_accuracy: 0.7288 - val_loss: 0.9684
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9850 - loss: 0.0488 - val_accuracy: 0.7126 - val_loss: 1.0610
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9764 - loss: 0.0716 - val_accuracy: 0.7249 - val_loss: 1.0117
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.9877 - loss: 0.0410 - val_accuracy: 0.7265 - val_loss: 1.0721
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.9838 - loss: 0.0532 - val_accuracy: 0.6549 - val_loss: 1.3562
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 53ms/step - accuracy: 0.9644 - loss: 0.1022 - val_accuracy: 0.7118 - val_loss: 1.1196
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 62ms/step - accuracy: 0.9923 - loss: 0.0304 - val_accuracy: 0.7204 - val_loss: 1.1445
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.9951 - loss: 0.0217 - val_accuracy: 0.7119 - val_loss: 1.2606
