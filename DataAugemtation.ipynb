# %% [markdown]
# # Data Augementation

# %%
import tensorflow  as tf
import keras 
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import  ImageDataGenerator

# %%
img = image.load_img('SQL\pp.jpg',target_size=(200,200))

# %%
# Define ImageDataGenerator with Augmentations
datagen = ImageDataGenerator(
    rotatidon_range=20,        # Rotate up to 20 degrees
    width_shift_range=0.2,    # Shift horizontally by 20%
    height_shift_range=0.2,   # Shift vertically by 20%
    shear_range=0.2,          # Apply shearing
    zoom_range=0.2,           # Apply zoom
    horizontal_flip=False,    # No horizontal flip (not needed for digits)
    rescale=1./255           # Normalize pixel values
)

# %%
img = image.img_to_array(img)

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
input_batch = img.reshape(1,200,200,3)

# %%
i =0 
for output_batch in datagen.flow(input_batch,batch_size=1,save_to_dir='SQL'):
    i = i + 1
    if i == 10 :
     break

# %% [markdown]
# # for complete folder

# %%
import os
import numpy as np
import pandas as pd
import random 
import cv2

# %%
my_dir = r"C:\Users\dell\Desktop\\JS\\archive\\train"

# %%
datagen = ImageDataGenerator(
    rotation_range=20,        # Rotate up to 20 degrees
    width_shift_range=0.2,    # Shift horizontally by 20%
    height_shift_range=0.2,   # Shift vertically by 20%
    shear_range=0.2,          # Apply shearing
    zoom_range=0.2,           # Apply zoom
    horizontal_flip=True,    # No horizontal flip (not needed for digits)
    rescale=1./255 )

# %%
categories =['cats','dogs']

# %%
data =[]
for i in categories :
 folder_path =os.path.join(my_dir,i) 
 if i == 'cats':
     label =0
 else:
     label =1
 for j in os.listdir(folder_path):
    img_path = os.path.join(folder_path,j)
    img =cv2.imread(img_path)
    img =cv2.resize(img,(150,150))
    data.append([img,label])

# %%
random.shuffle(data)
x =[]
y =[]
for i in data:
    x.append(i[0])
    y.append(i[1])

# %%
x= np.array(x)
y =np.array(y)

# %%
x.shape
# Out:
# (20000, 150, 150, 3)

# %%
x =x/255

# %%
from keras import Sequential
from keras.layers import Dense,Conv2D,Flatten ,MaxPooling2D,Dropout

# %%
model =Sequential()
model.add(Conv2D(32,kernel_size=(3,3) ,input_shape =(150,150,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation='softmax'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(x,y,validation_split=(0.2),epochs=5)
# Out:
# Epoch 1/5
# C:\Users\dell\AppData\Roaming\Python\Python311\site-packages\keras\src\ops\nn.py:907: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 168s 319ms/step - accuracy: 0.5023 - loss: 0.6696 - val_accuracy: 0.5130 - val_loss: 0.5556
# Epoch 2/5
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 167s 334ms/step - accuracy: 0.4946 - loss: 0.5257 - val_accuracy: 0.5130 - val_loss: 0.4829
# Epoch 3/5
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 148s 296ms/step - accuracy: 0.4956 - loss: 0.4522 - val_accuracy: 0.5130 - val_loss: 0.4471
# Epoch 4/5
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 143s 285ms/step - accuracy: 0.4932 - loss: 0.4017 - val_accuracy: 0.5130 - val_loss: 0.4195
# Epoch 5/5
# ...

# %%
batch_size =16 

# augemntation
train_datagen = ImageDataGenerator(
    rotation_range=20,        # Rotate up to 20 degrees
    width_shift_range=0.2,    # Shift horizontally by 20%
    height_shift_range=0.2,   # Shift vertically by 20%
    shear_range=0.2,          # Apply shearing
    zoom_range=0.2,           # Apply zoom
    horizontal_flip=True,    # No horizontal flip (not needed for digits)
    rescale=1./255 )

test_datagen = ImageDataGenerator(rescale =1./255)

input_train = r"C:\\Users\dell\Desktop\\JS\\archive\\train"
train_generator = train_datagen.flow_from_directory( 
    input_train,target_size =(150,150) ,batch_size=batch_size ,class_mode ='binary'
    
)

 #valid_generator =test_datagen.flow_from_directory( 
 #   'archive/valid',target_size =(150,150),batch_size=batch_size
  #  , class_mode ='binary')


model =Sequential()
model.add(Conv2D(32,kernel_size=(3,3) ,input_shape =(150,150,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation='softmax'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# Found 20000 images belonging to 2 classes.
# C:\Users\dell\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(train_generator,steps_per_epoch =2000 //batch_size,epochs =5)
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# C:\Users\dell\AppData\Roaming\Python\Python311\site-packages\keras\src\ops\nn.py:907: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 44s 324ms/step - accuracy: 0.5291 - loss: 0.7012
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 39s 310ms/step - accuracy: 0.4990 - loss: 0.6932
# Epoch 3/5
# ...

# %% [markdown]
# # Dog vs Cat classification

# %%
#Another way
train_data= keras.utils.image_dataset_from_directory (
    directory=  r"C:\Users\dell\Desktop\\JS\\archive\\train",
    label_mode='int',
    labels= 'inferred'  # to consider subdirectory also
    ,batch_size=32,
    image_size=(256,256) ,
 )
# Out:
# Found 20000 files belonging to 2 classes.

# %%
batch_size =16 

# augemntation
train_datagen = ImageDataGenerator(
    rotation_range=20,        # Rotate up to 20 degrees
    width_shift_range=0.2,    # Shift horizontally by 20%
    height_shift_range=0.2,   # Shift vertically by 20%
    shear_range=0.2,          # Apply shearing
    zoom_range=0.2,           # Apply zoom
    horizontal_flip=True,    # No horizontal flip (not needed for digits)
    rescale=1./255 )

test_datagen = ImageDataGenerator(rescale =1./255)

input_train = r"C:\\Users\dell\Desktop\\JS\\archive\\train"
train_generator = train_datagen.flow_from_directory( 
    input_train,target_size =(150,150) ,batch_size=batch_size ,class_mode ='binary'
    
)

 #valid_generator =test_datagen.flow_from_directory( 
 #   'archive/valid',target_size =(150,150),batch_size=batch_size
  #  , class_mode ='binary')


model =Sequential()
model.add(Conv2D(32,kernel_size=(3,3) ,input_shape =(150,150,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation='softmax'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# Found 20000 images belonging to 2 classes.
# C:\Users\dell\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
